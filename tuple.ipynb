# %%
#
my_tuple=('tuple',12,12.4)
print(my_tuple)
print(type(my_tuple))
# Out:
# ('tuple', 12, 12.4)
# <class 'tuple'>

# %%
my_tuple=('data science',12,34.5,45)
print(my_tuple[0])
print(my_tuple[3])
print(my_tuple[:1])
print(my_tuple[::])
print(my_tuple[2:])
print(my_tuple[2:3])
print(my_tuple[:-3])
print(my_tuple[::2])
# Out:
# data science
# 45
# ('data science',)
# ('data science', 12, 34.5, 45)
# (34.5, 45)
# (34.5,)
# ('data science',)
# ('data science', 34.5)

# %% [markdown]
# tuple is an immutable
# add, dele doesn't accept

# %%
#
a=(12,34,56,77)

a[2]=1223
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-90d9d804c51f> in <cell line: 4>()
#       2 a=(12,34,56,77)
#       3
# ----> 4 a[2]=1223
#       5 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
a=(12,34,56,77)
del a[3]
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-94de2e54de5c> in <cell line: 2>()
#       1 a=(12,34,56,77)
# ----> 2 del a[3]
#       3 print(a)
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# tuple boilt_in function
# count
# index

# %%
#count
a=(12,34,56,77,45,77)
a.count(77)
# Out:
# 2

# %%
# index
a=(12,34,56,77)
a.index(56)
# Out:
# 2

# %%
a=(12,34,56,78,9,8,64,43,3,5)
print(a)
b=list(a)
print(b)
b.remove(78)
print(b)
# Out:
# (12, 34, 56, 78, 9, 8, 64, 43, 3, 5)
# [12, 34, 56, 78, 9, 8, 64, 43, 3, 5]
# [12, 34, 56, 9, 8, 64, 43, 3, 5]
