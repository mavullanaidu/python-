# %%
my_dict={ 'name':'naidu','age':23}
print(my_dict)
print(type(my_dict))
# Out:
# {'name': 'naidu', 'age': 23}
# <class 'dict'>

# %%
# we gives multiple values
my_dict={'name':['naidu','guna','mavulla'],'age':[23,24,25],'salary':[100,200,444]}
print(my_dict)
print(my_dict['name'])
# Out:
# {'name': ['naidu', 'guna', 'mavulla'], 'age': [23, 24, 25], 'salary': [100, 200, 444]}
# ['naidu', 'guna', 'mavulla']

# %%
import pandas as pd
pd.DataFrame(my_dict)
# Out:
#       name  age  salary
# 0    naidu   23     100
# 1     guna   24     200
# 2  mavulla   25     444

# %%
# we will gives any data type# list dont accept key
my_list={'age':23,'salary':2345.5,'loc':'hyd','country':(234),'course':{"da"}}
print(my_dict)
# Out:
# {'name': ['naidu', 'guna', 'mavulla'], 'age': [23, 24, 25], 'salary': [100, 200, 444]}

# %%
my_dict={'name':['naidu','guna','mavulla'],'age':[23,24,25],'salary':[100,200,444]}
print(my_dict)
print(my_dict['name'])
prin(my_dict['age'])
# Out:
# {'name': ['naidu', 'guna', 'mavulla'], 'age': [23, 24, 25], 'salary': [100, 200, 444]}
# ['naidu', 'guna', 'mavulla']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e822fae15b69> in <cell line: 4>()
#       2 print(my_dict)
#       3 print(my_dict['name'])
# ----> 4 prin(my_dict['age'])
#
# NameError: name 'prin' is not defined

# %%
for a in range(12,21):
  if a==20:
    print()
# Out:
# 20
