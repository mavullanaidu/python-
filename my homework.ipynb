# %%
5
4
# Out:
# 4

# %%
-4
-5
# Out:
# -5

# %%
a=2
print(a)
# Out:
# 2

# %%
print('hello naidu')
print("hello guna naidu")
print("""hello mavulla naidu guna""")
# Out:
# hello naidu
# hello guna naidu
# hello mavulla naidu guna

# %% [markdown]
# # hello guna
# ## hello guna naidu
# ### hello guna naidu
# #### i am from hyd
# ##### i am eat food
# ###### are you eating food
# #######yes i am eattinf food this is not consider seven # symbols only consider six symbols only

# %%
a=4
print(a)
# Out:
# 4

# %%
print("my self guna naidu i am from srikakulam my graduation is completed in vizianagaram and my post graduation completed in vijayawada my hobbes is playing vally ball")
# Out:
# my self guna naidu i am from srikakulam my graduation is completed in vizianagaram and my post graduation completed in vijayawada my hobbes is playing vally ball

# %%
#some programs
4+4
4+4-4-2
8*6-3
56%5
3**3
print(4+4)
print(4+4-4-2)
print(8*6-3)
print(56%5)
print(3**3)
print('4+4')
# Out:
# 8
# 2
# 45
# 1
# 27
# 4+4

# %%
a=3
b=5
c=a+b
print(a+b)
print(c)
print(a)
print(b)
# Out:
# 8
# 8
# 3
# 5

# %% [markdown]
# we are adding new variable

# %%
a=34
b=66
c=a+b
print(c)
print(34-66)
print(34%66)
print(66/34)
print(66//34)
print(66**34)
# Out:
# 100
# -32
# 34
# 1.9411764705882353
# 1
# 73197088768608101145353522393209837987167745985959663748775936

# %% [markdown]
# #data types

# %%
a=-4
print(a)
print(type(a))
# Out:
# -4
# <class 'int'>

# %%
a=4
b=-5
print(a,b)
print(a+b)
# Out:
# 4 -5
# -1

# %%
a=r=t=44
print(a,r,t)
print()
# Out:
# 44 44 44
# a
#  r/n t/n

# %% [markdown]
# # no white spaces in variable name

# %%
  w wv=3
print(w wv)
# Out:
#   File "<ipython-input-72-10a3878ef8b3>", line 1
#     w wv=3
#       ^
# SyntaxError: invalid syntax

# %%
guna ss=4
print(guna ss)
# Out:
#   File "<ipython-input-73-3c7c0b7d281b>", line 1
#     guna ss=4
#          ^
# SyntaxError: invalid syntax

# %%
guna_ss=4
print(guna_ss)
# Out:
# 4

# %% [markdown]
# # variable name is case sensitive

# %%
ABE=3
print(ABE)
abe=5
ABE=4
print(ABE)
print(abe)
# Out:
# 3
# 4
# 5

# %% [markdown]
# #can't use special symbols in variable names

# %%
$=5
print($)
# Out:
#   File "<ipython-input-79-df7233f1fc54>", line 1
#     $=5
#     ^
# SyntaxError: invalid syntax

# %%
&='naveen'
print(&)
# Out:
#   File "<ipython-input-80-72c10b9c37a3>", line 1
#     &='naveen'
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # variable name can't start with numbers

# %%
13='guna'
print(13)
# Out:
#   File "<ipython-input-81-009f598b6e6b>", line 1
#     13='guna'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
_13=4
print(_13)
_python12='gunanaidu'
print(_python12)
# Out:
# 4
# gunanaidu

# %%
coursename= 'data science'
print(coursename)
_course33='$name'
print(_course33)
# Out:
# data science
# $name

# %%
name,age,marks='naidu','23','80'
print(name,age,marks)
# Out:
# naidu 23 80

# %%
name='guna'
name
# Out:
# 'guna'

# %%
b=4
b
# Out:
# 4

# %%
gender='male'
gender
# Out:
# 'male'

# %%
name, age, date='mavulla naidu',24,33
print(name,age,date)
# Out:
# mavulla naidu 24 33

# %% [markdown]
# #variable con't start with keywords

# %%
if=3
print(if)
# Out:
#   File "<ipython-input-99-a8e0ed2847af>", line 1
#     if=3
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #multipule assignment variables

# %%
age,name,city='23','mavulla naidu','mumbai'
b=age,name,city
print(b)
print(age)
print(name)
print(city)
print(age,name,city)
# Out:
# ('23', 'mavulla naidu', 'mumbai')
# 23
# mavulla naidu
# mumbai
# 23 mavulla naidu mumbai

# %% [markdown]
# # we can assign the same value

# %%
age=fav=23
print(age,fav)
# Out:
# 23 23

# %%
#swapping variables

# %%
a='5'
b='6'
a,b=b,a
print(a,b)
# Out:
# 6 5

# %%
name,Name='guna','naidu'
print(name,Name)
name,Name=Name,name
print(name,Name)
# Out:
# guna naidu
# naidu guna

# %% [markdown]
# #type conversion
# #convert one data type to another date type

# %%
d='3'
print(d)
print(type(d))
# Out:
# 3
# <class 'str'>

# %% [markdown]
# #interger to string

# %%
d=3
print(d)
print(type(d))
name=str(d)
print(name)
print(type(name))
# Out:
# 3
# <class 'int'>
# 3
# <class 'str'>

# %% [markdown]
# #
# convert string to integer

# %%
name='12'
print(name)
print(type(name))
guna=int(name)
print(type(guna))
# Out:
# 12
# <class 'str'>
# <class 'int'>

# %% [markdown]
# #convert integer to float

# %%
name=12
print(name)
print(type(name))
guna=float(name)
print(name)
print(type(guna))
# Out:
# 12
# <class 'int'>
# 12
# <class 'float'>

# %%
a=23
print(a)
print(type(a))
b=float(a)
print(b)
print(type(b))
# Out:
# 23
# <class 'int'>
# 23.0
# <class 'float'>

# %% [markdown]
# convert float to integer

# %%
b=12.4
print(b)
print(type(b))
c=int(b)
print(c)
print(type(c))
# Out:
# 12.4
# <class 'float'>
# 12
# <class 'int'>

# %% [markdown]
# #convert float to string

# %%
v=12.44
print(v)
print(type(v))
m=str(v)
print(m)
print(type(m))
# Out:
# 12.44
# <class 'float'>
# 12.44
# <class 'str'>

# %% [markdown]
# #string to float

# %%
g="23"
print(g)
print(type(g))
u=float(g)
print(u)
print(type(u))
# Out:
# 23
# <class 'str'>
# 23.0
# <class 'float'>

# %% [markdown]
# #python is collection of built_in function and libraries import math

# %%
import math
math.tan(45)
# Out:
# 1.6197751905438615

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.cos(0)
# Out:
# 1.0

# %%
import math
math.factorial(4)
# Out:
# 24

# %% [markdown]
# #print() function in python will let us  write to  consul output
# print is used to print what ever we write in the inside the string
#
# examples

# %%
a='guna'
print(a)
print('name',a) #we can use some relations
#they are two techniques
#comma is used to adding any data types
# Out:
# guna
# name guna

# %%
age=23
print(age)
print(f'i am ,{age} years old')
# Out:
# 23
# i am ,23 years old

# %% [markdown]
# #operator

# %% [markdown]
# arithmetic operator

# %%
#addition
a=23
b=23
a+b
# Out:
# 46

# %%
a=23
b=23
print(a+b)
# Out:
# 46

# %%
a=23
b=23
c=a+b
print(c)
# Out:
# 46

# %%
a=23
b=23
print('addition',a+b)
# Out:
# addition 46

# %%
# subtraction
45-56
# Out:
# -11

# %%
45-6
# Out:
# 39

# %%
a=12
b=4
print(a-b)
# Out:
# 8

# %%
a=2
b=4
print(a-b)
# Out:
# -2

# %%
a=23
b=240
print(a-b)
c=a-b
d=b-a
print(c)
print(d)
# Out:
# -217
# -217
# 217

# %%
a=23
b=240
print('subtraction',a-b,b-a)
c=b-a
print(c)
# Out:
# subtraction -217 217
# 217

# %% [markdown]
# #multiplication

# %%
3*3
# Out:
# 9

# %%
a=3
b=6
print(a*b)
c=a*b
d=a+b
e=a-b
print(c)
print('multiplication',c)
print('multiplication',c,'addition',d,'subtraction',e)
# Out:
# 18
# 18
# multiplication 18
# multiplication 18 addition 9 subtraction -3

# %%
# division
34/3
a=34
b=3
print(a/b)
c=a/b
print(c)
print(type(c))
print(type(a))
print('division',c)
# Out:
# 11.333333333333334
# 11.333333333333334
# <class 'float'>
# <class 'int'>
# division 11.333333333333334

# %%
# floor division
a=56
b=4
a//b
print(a//b)
c=a//b
print(c)
print('floor division',c)
print('floor division',a//b)
# Out:
# 14
# 14
# floor division 14
# floor division 14

# %%
#mod
25%3
# Out:
# 1

# %%
a=45
b=4
c=a%b
print(a%b)
print('mod',a%b)
print(c)
print(type(c))
# Out:
# 1
# mod 1
# 1
# <class 'int'>

# %%
#power

x=3
y=2
z=5
pow(x,y,z)
# Out:
# 4

# %%
x=3
y=2
z=5
c=x,y,z
print(pow(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-1ed2f734d81e> in <cell line: 5>()
#       3 z=5
#       4 c=x,y,z
# ----> 5 print(pow(c))
#
# TypeError: pow() missing required argument 'exp' (pos 2)

# %%
#relational operators
# the difference between = and ==
#= will take right side operator and save in left side
a=10
print(a)
# Out:
# 10

# %%
#== means if will check both sides are equal or not
10==11
10==10
# Out:
# True

# %%
#> true if left operand is grether than right
a=12
b=11
a>b
print(a>b)
c=a>b
print(c)
# Out:
# True
# True

# %%
a=34
b=45
a>b
b>a
# Out:
# True

# %%
#< true if left operand is less than rihgt


a=11
b=12
a<b
# Out:
# True

# %%
#>= true if left operand is grether than equal to right operand
a=56
b=55
a>=b
# Out:
# True

# %%
a=66
b=68
a>=b
# Out:
# False

# %%
#<= true if left operand is less than equal to right operand
a=23
b=78
a<=b
# Out:
# True

# %%
#!= not equal
a=12
b=12
a!=b
# Out:
# False

# %%
a=12
b=34
a!=b
# Out:
# True

# %% [markdown]
# # python data structure or data types

# %%
#strings
#memory allocation
#indexing
#slicing
#skipping
#built_in function

# %%
a='mavulla naidu'
print(a)
#indexing means we are calling from only one character in the string
# indexindg is start from '0'
#they are two types
#forward indexindg  start from "0"
#backword indexing  start from "-1"
a="mavulla naidu" # save in memory
print(a)
# Out:
# mavulla naidu
# mavulla naidu

# %%
#forward index
a='mavulla naidu'
print(a[2])
print(a[7])
print(a[0])
print(a[9])
# Out:
# v
#
# m
# a

# %%
# backword indexind
a='mavulla naidu'
print(a)
print(a[-2])
print(a[-1])
# Out:
# mavulla naidu
# d
# u

# %% [markdown]
# # slicing

# %%
a= 'mavulla naidu i love my india'
#slicind is calling from start_index : end_index separeted by colon
print(a[2:9])
print(a[2:12])
# Out:
# vulla n
# vulla naid

# %%
#they are three stable formulas
# 1.slice is from the start
a= 'i am eating food'  #by leaving out the start index the range will be start at the frist character
print(a[:7])
# Out:
# i am ea

# %%
a='naku kadhu niku chala overaction'
print(a[2:17])
print(a[:20]) # colon is start
print(a[2:]) # colon is end
print(a[::-1]) # reverse
print(a[-5:-1]) # negative index
# Out:
# ku kadhu niku c
# naku kadhu niku chal
# ku kadhu niku chala overaction
# noitcarevo alahc ukin uhdak ukan
# ctio

# %%
# skipping
a='nuvvu bratikee unnavaa'
print(a[::2])
print(a[::4])
# Out:
# nvubaie naa
# nuaena

# %%
# python strindg built_in functions
# capitalize()
# title()
# lower()
# upper()
# islower()
# isupper()
# isalpha()
# isalnum()
# startwith()
# endwith()
# index()
#count()

# %%
#capitalize()  will capital the starting letter and renaing letters are small
a= 'i love my india'
print(a)
b=a.capitalize()
print(b)
# Out:
# i love my india
# I love my india

# %%
# title convert the first charecter in each word to upper case
a='chala rojulu avvutudhi group lo message chesi'
print(a)
a.title()
b=a.title()
print(b)
# Out:
# chala rojulu avvutudhi group lo message chesi
# Chala Rojulu Avvutudhi Group Lo Message Chesi

# %%
# lower  IT WILL CONVERTS CAPITAL LETTERS TO small
a='IT WILL CONVERTS CAPITAL LETTERS TO SMALL'
a.lower()
print(a)
b=a.lower()
print(b)
# Out:
# IT WILL CONVERTS CAPITAL LETTERS TO SMALL
# it will converts capital letters to small

# %%
#upper it will converts lower to upper
a='upper it will converts lower to upper'
print(a)
a.upper()
# Out:
# upper it will converts lower to upper
# 'UPPER IT WILL CONVERTS LOWER TO UPPER'

# %%
# is lower  check the value is true or flase
a='guna'
print(a.islower())
# Out:
# True

# %%
a='Duna'
print(a.islower())
# Out:
# False

# %%
# is upper
a='GUNANAIDU'
print(a.isupper())
# Out:
# True

# %%
a='gunAASD'
print(a.isupper())
# Out:
# False

# %%
# is alapha
a='isalapha'
print(a.isalpha())
# Out:
# True

# %%
a='AAASs'
print(a.isalpha())
# Out:
# True

# %%
# isnumeric
a='1223456'
print(a.isnumeric())
# Out:
# True

# %%
a='2345d'
print(a.isnumeric())
# Out:
# False

# %%
#isalnum
a='guna1435'
print(a.isalnum())
# Out:
# True

# %%
#startwith()
a='guna naidu'
print(a.startswith('g'))
# Out:
# True

# %%
a='gunanaidu'
print(a.startwith('g'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-17eddf5ff21f> in <cell line: 2>()
#       1 a='gunanaidu'
# ----> 2 print(a.startwith('g'))
#
# AttributeError: 'str' object has no attribute 'startwith'

# %%
#endwith
a='gunanaidu'
print(a.endswith('u'))
# Out:
# True

# %%
#count
a='gunanaidu'
print(a.count('n'))
# Out:
# 2

# %%
# index
a='guna naidu'
print(a.index('a'))
# Out:
# 3

# %%
# lenght
a= 'gunanaidu'
print(len(a))
# Out:
# 9

# %%
print("guna/n naidu")
# Out:
# guna/n naidu
